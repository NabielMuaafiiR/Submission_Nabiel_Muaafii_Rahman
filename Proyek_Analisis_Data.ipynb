# %% [markdown]
# # Proyek Analisis Data: Air-quality-dataset
# - **Nama:** Nabiel Muaafii Rahman
# - **Email:** mc001d5y0851@student.devacademy.id
# - **ID Dicoding:** MC001D5Y0851

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana curah hujan tiap bulannya dalam kurun waktu 2013/2017?
# - Faktor apa yang menyebabkan curah hujan?
# - Daerah mana dengan curah hujan tertinggi pada tiap tahun?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
Aotizhongxin_df = pd.read_csv('/content/drive/MyDrive/DBS/TUGAS ANALISIS DATA/Air-quality-dataset/PRSA_Data_20130301-20170228/PRSA_Data_Aotizhongxin_20130301-20170228.csv', index_col='No')
Aotizhongxin_df.head()
# Out:
#     year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# No
# 1   2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 2   2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 3   2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 4   2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 5   2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#       PRES  DEWP  RAIN   wd  WSPM       station
# No
# 1   1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 2   1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 3   1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 4   1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 5   1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
Changping_df = pd.read_csv('/content/drive/MyDrive/DBS/TUGAS ANALISIS DATA/Air-quality-dataset/PRSA_Data_20130301-20170228/PRSA_Data_Changping_20130301-20170228.csv', index_col='No')
Changping_df.head()
# Out:
#     year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# No
# 1   2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 2   2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 3   2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 4   2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 5   2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#       PRES  DEWP  RAIN   wd  WSPM    station
# No
# 1   1020.8 -19.7   0.0    E   0.5  Changping
# 2   1021.3 -19.0   0.0  ENE   0.7  Changping
# 3   1021.3 -19.9   0.0  ENE   0.2  Changping
# 4   1021.8 -19.1   0.0  NNE   1.0  Changping
# 5   1022.3 -19.4   0.0    N   2.1  Changping

# %%
Dingling_df = pd.read_csv('/content/drive/MyDrive/DBS/TUGAS ANALISIS DATA/Air-quality-dataset/PRSA_Data_20130301-20170228/PRSA_Data_Dingling_20130301-20170228.csv', index_col='No')
Dingling_df.head()
# Out:
#     year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP    PRES  \
# No
# 1   2013      3    1     0    4.0   4.0  3.0  NaN  200.0  82.0  -2.3  1020.8
# 2   2013      3    1     1    7.0   7.0  3.0  NaN  200.0  80.0  -2.5  1021.3
# 3   2013      3    1     2    5.0   5.0  3.0  2.0  200.0  79.0  -3.0  1021.3
# 4   2013      3    1     3    6.0   6.0  3.0  NaN  200.0  79.0  -3.6  1021.8
# 5   2013      3    1     4    5.0   5.0  3.0  NaN  200.0  81.0  -3.5  1022.3
#
#     DEWP  RAIN   wd  WSPM   station
# No
# 1  -19.7   0.0    E   0.5  Dingling
# 2  -19.0   0.0  ENE   0.7  Dingling
# 3  -19.9   0.0  ENE   0.2  Dingling
# 4  -19.1   0.0  NNE   1.0  Dingling
# 5  -19.4   0.0    N   2.1  Dingling

# %%
Dongsi_df = pd.read_csv('/content/drive/MyDrive/DBS/TUGAS ANALISIS DATA/Air-quality-dataset/PRSA_Data_20130301-20170228/PRSA_Data_Dongsi_20130301-20170228.csv', index_col='No')
Dongsi_df.head()
# Out:
#     year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP    PRES  \
# No
# 1   2013      3    1     0    9.0   9.0  3.0  17.0  300.0  89.0  -0.5  1024.5
# 2   2013      3    1     1    4.0   4.0  3.0  16.0  300.0  88.0  -0.7  1025.1
# 3   2013      3    1     2    7.0   7.0  NaN  17.0  300.0  60.0  -1.2  1025.3
# 4   2013      3    1     3    3.0   3.0  5.0  18.0    NaN   NaN  -1.4  1026.2
# 5   2013      3    1     4    3.0   3.0  7.0   NaN  200.0  84.0  -1.9  1027.1
#
#     DEWP  RAIN   wd  WSPM station
# No
# 1  -21.4   0.0  NNW   5.7  Dongsi
# 2  -22.1   0.0   NW   3.9  Dongsi
# 3  -24.6   0.0  NNW   5.3  Dongsi
# 4  -25.5   0.0    N   4.9  Dongsi
# 5  -24.5   0.0  NNW   3.2  Dongsi

# %%
Guanyuan_df = pd.read_csv('/content/drive/MyDrive/DBS/TUGAS ANALISIS DATA/Air-quality-dataset/PRSA_Data_20130301-20170228/PRSA_Data_Guanyuan_20130301-20170228.csv', index_col='No')
Guanyuan_df.head()
# Out:
#     year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# No
# 1   2013      3    1     0    4.0   4.0  14.0  20.0  300.0  69.0  -0.7
# 2   2013      3    1     1    4.0   4.0  13.0  17.0  300.0  72.0  -1.1
# 3   2013      3    1     2    3.0   3.0  10.0  19.0  300.0  69.0  -1.1
# 4   2013      3    1     3    3.0   6.0   7.0  24.0  400.0  62.0  -1.4
# 5   2013      3    1     4    3.0   6.0   5.0  14.0  400.0  71.0  -2.0
#
#       PRES  DEWP  RAIN   wd  WSPM   station
# No
# 1   1023.0 -18.8   0.0  NNW   4.4  Guanyuan
# 2   1023.2 -18.2   0.0    N   4.7  Guanyuan
# 3   1023.5 -18.2   0.0  NNW   5.6  Guanyuan
# 4   1024.5 -19.4   0.0   NW   3.1  Guanyuan
# 5   1025.2 -19.5   0.0    N   2.0  Guanyuan

# %%
Gucheng_df = pd.read_csv('/content/drive/MyDrive/DBS/TUGAS ANALISIS DATA/Air-quality-dataset/PRSA_Data_20130301-20170228/PRSA_Data_Gucheng_20130301-20170228.csv', index_col='No')
Gucheng_df.head()
# Out:
#     year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP    PRES  \
# No
# 1   2013      3    1     0    6.0  18.0  5.0  NaN  800.0  88.0   0.1  1021.1
# 2   2013      3    1     1    6.0  15.0  5.0  NaN  800.0  88.0  -0.3  1021.5
# 3   2013      3    1     2    5.0  18.0  NaN  NaN  700.0  52.0  -0.7  1021.5
# 4   2013      3    1     3    6.0  20.0  6.0  NaN    NaN   NaN  -1.0  1022.7
# 5   2013      3    1     4    5.0  17.0  5.0  NaN  600.0  73.0  -1.3  1023.0
#
#     DEWP  RAIN   wd  WSPM  station
# No
# 1  -18.6   0.0   NW   4.4  Gucheng
# 2  -19.0   0.0   NW   4.0  Gucheng
# 3  -19.8   0.0  WNW   4.6  Gucheng
# 4  -21.2   0.0    W   2.8  Gucheng
# 5  -21.4   0.0  WNW   3.6  Gucheng

# %%
Huairou_df = pd.read_csv('/content/drive/MyDrive/DBS/TUGAS ANALISIS DATA/Air-quality-dataset/PRSA_Data_20130301-20170228/PRSA_Data_Huairou_20130301-20170228.csv', index_col='No')
Huairou_df.head()
# Out:
#     year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP    PRES  \
# No
# 1   2013      3    1     0    7.0   7.0  3.0  2.0  100.0  91.0  -2.3  1020.3
# 2   2013      3    1     1    4.0   4.0  3.0  NaN  100.0  92.0  -2.7  1020.8
# 3   2013      3    1     2    4.0   4.0  NaN  NaN  100.0  91.0  -3.2  1020.6
# 4   2013      3    1     3    3.0   3.0  3.0  2.0    NaN   NaN  -3.3  1021.3
# 5   2013      3    1     4    3.0   3.0  7.0  NaN  300.0  86.0  -4.1  1022.1
#
#     DEWP  RAIN   wd  WSPM  station
# No
# 1  -20.7   0.0  WNW   3.1  Huairou
# 2  -20.5   0.0  NNW   1.5  Huairou
# 3  -21.4   0.0   NW   1.8  Huairou
# 4  -23.7   0.0  NNW   2.4  Huairou
# 5  -22.7   0.0  NNW   2.2  Huairou

# %%
Nongzhanguan_df = pd.read_csv('/content/drive/MyDrive/DBS/TUGAS ANALISIS DATA/Air-quality-dataset/PRSA_Data_20130301-20170228/PRSA_Data_Nongzhanguan_20130301-20170228.csv', index_col='No')
Nongzhanguan_df.head()
# Out:
#     year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP    PRES  \
# No
# 1   2013      3    1     0    5.0  14.0  4.0  12.0  200.0  85.0  -0.5  1024.5
# 2   2013      3    1     1    8.0  12.0  6.0  14.0  200.0  84.0  -0.7  1025.1
# 3   2013      3    1     2    3.0   6.0  5.0  14.0  200.0  83.0  -1.2  1025.3
# 4   2013      3    1     3    5.0   5.0  5.0  14.0  200.0  84.0  -1.4  1026.2
# 5   2013      3    1     4    5.0   5.0  6.0  21.0  200.0  77.0  -1.9  1027.1
#
#     DEWP  RAIN   wd  WSPM       station
# No
# 1  -21.4   0.0  NNW   5.7  Nongzhanguan
# 2  -22.1   0.0   NW   3.9  Nongzhanguan
# 3  -24.6   0.0  NNW   5.3  Nongzhanguan
# 4  -25.5   0.0    N   4.9  Nongzhanguan
# 5  -24.5   0.0  NNW   3.2  Nongzhanguan

# %%
Shunyi_df = pd.read_csv('/content/drive/MyDrive/DBS/TUGAS ANALISIS DATA/Air-quality-dataset/PRSA_Data_20130301-20170228/PRSA_Data_Shunyi_20130301-20170228.csv', index_col='No')
Shunyi_df.head()
# Out:
#     year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP    PRES  \
# No
# 1   2013      3    1     0    3.0   6.0  3.0  8.0  300.0  44.0  -0.9  1025.8
# 2   2013      3    1     1   12.0  12.0  3.0  7.0  300.0  47.0  -1.1  1026.1
# 3   2013      3    1     2   14.0  14.0  NaN  7.0  200.0  22.0  -1.7  1026.2
# 4   2013      3    1     3   12.0  12.0  3.0  5.0    NaN   NaN  -2.1  1027.3
# 5   2013      3    1     4   12.0  12.0  3.0  NaN  200.0  11.0  -2.4  1027.7
#
#     DEWP  RAIN  wd  WSPM station
# No
# 1  -20.5   0.0  NW   9.3  Shunyi
# 2  -21.3   0.0  NW   9.4  Shunyi
# 3  -23.0   0.0  NW   8.6  Shunyi
# 4  -23.3   0.0  NW   6.6  Shunyi
# 5  -22.9   0.0  NW   4.5  Shunyi

# %%
Tiantan_df = pd.read_csv('/content/drive/MyDrive/DBS/TUGAS ANALISIS DATA/Air-quality-dataset/PRSA_Data_20130301-20170228/PRSA_Data_Tiantan_20130301-20170228.csv', index_col='No')
Tiantan_df.head()
# Out:
#     year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP    PRES  \
# No
# 1   2013      3    1     0    6.0   6.0  4.0   8.0  300.0  81.0  -0.5  1024.5
# 2   2013      3    1     1    6.0  29.0  5.0   9.0  300.0  80.0  -0.7  1025.1
# 3   2013      3    1     2    6.0   6.0  4.0  12.0  300.0  75.0  -1.2  1025.3
# 4   2013      3    1     3    6.0   6.0  4.0  12.0  300.0  74.0  -1.4  1026.2
# 5   2013      3    1     4    5.0   5.0  7.0  15.0  400.0  70.0  -1.9  1027.1
#
#     DEWP  RAIN   wd  WSPM  station
# No
# 1  -21.4   0.0  NNW   5.7  Tiantan
# 2  -22.1   0.0   NW   3.9  Tiantan
# 3  -24.6   0.0  NNW   5.3  Tiantan
# 4  -25.5   0.0    N   4.9  Tiantan
# 5  -24.5   0.0  NNW   3.2  Tiantan

# %%
Wanliu_df = pd.read_csv('/content/drive/MyDrive/DBS/TUGAS ANALISIS DATA/Air-quality-dataset/PRSA_Data_20130301-20170228/PRSA_Data_Wanliu_20130301-20170228.csv', index_col='No')
Wanliu_df.head()
# Out:
#     year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP    PRES  \
# No
# 1   2013      3    1     0    8.0   8.0  6.0  28.0  400.0  52.0  -0.7  1023.0
# 2   2013      3    1     1    9.0   9.0  6.0  28.0  400.0  50.0  -1.1  1023.2
# 3   2013      3    1     2    3.0   6.0  NaN  19.0  400.0  55.0  -1.1  1023.5
# 4   2013      3    1     3   11.0  30.0  8.0  14.0    NaN   NaN  -1.4  1024.5
# 5   2013      3    1     4    3.0  13.0  9.0   NaN  300.0  54.0  -2.0  1025.2
#
#     DEWP  RAIN   wd  WSPM station
# No
# 1  -18.8   0.0  NNW   4.4  Wanliu
# 2  -18.2   0.0    N   4.7  Wanliu
# 3  -18.2   0.0  NNW   5.6  Wanliu
# 4  -19.4   0.0   NW   3.1  Wanliu
# 5  -19.5   0.0    N   2.0  Wanliu

# %%
Wanshouxigong_df = pd.read_csv('/content/drive/MyDrive/DBS/TUGAS ANALISIS DATA/Air-quality-dataset/PRSA_Data_20130301-20170228/PRSA_Data_Wanshouxigong_20130301-20170228.csv', index_col='No')
Wanshouxigong_df.head()
# Out:
#     year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP    PRES  \
# No
# 1   2013      3    1     0    9.0   9.0  6.0  17.0  200.0  62.0   0.3  1021.9
# 2   2013      3    1     1   11.0  11.0  7.0  14.0  200.0  66.0  -0.1  1022.4
# 3   2013      3    1     2    8.0   8.0  NaN  16.0  200.0  59.0  -0.6  1022.6
# 4   2013      3    1     3    8.0   8.0  3.0  16.0    NaN   NaN  -0.7  1023.5
# 5   2013      3    1     4    8.0   8.0  3.0   NaN  300.0  36.0  -0.9  1024.1
#
#     DEWP  RAIN   wd  WSPM        station
# No
# 1  -19.0   0.0  WNW   2.0  Wanshouxigong
# 2  -19.3   0.0  WNW   4.4  Wanshouxigong
# 3  -19.7   0.0  WNW   4.7  Wanshouxigong
# 4  -20.9   0.0   NW   2.6  Wanshouxigong
# 5  -21.7   0.0  WNW   2.5  Wanshouxigong

# %%
df = pd.concat([Aotizhongxin_df, Changping_df, Dingling_df, Dongsi_df, Guanyuan_df, Gucheng_df, Huairou_df, Nongzhanguan_df, Shunyi_df, Tiantan_df, Wanliu_df, Wanshouxigong_df], ignore_index=True)
df.head()
# Out:
#    year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP    PRES  \
# 0  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7  1023.0
# 1  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1  1023.2
# 2  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1  1023.5
# 3  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4  1024.5
# 4  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0  1025.2
#
#    DEWP  RAIN   wd  WSPM       station
# 0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1 -18.2   0.0    N   4.7  Aotizhongxin
# 2 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3 -19.4   0.0   NW   3.1  Aotizhongxin
# 4 -19.5   0.0    N   2.0  Aotizhongxin

# %%
df.columns
# Out:
# Index(['year', 'month', 'day', 'hour', 'PM2.5', 'PM10', 'SO2', 'NO2', 'CO',
#        'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM', 'station'],
#       dtype='object')

# %%
df.shape
# Out:
# (420768, 17)

# %% [markdown]
# **Insight:**
# - Dilakukan merging dari semua data
# - Terdapat 18 kolom dengan 17 kolom fitur dan 1 kolom index dan 420.768 baris pada data kualitas udara
# - Data diatas dengan file yang berbeda memiliki fitur/kolom yang sama, yang membedakan hanya daerahnya saja

# %% [markdown]
# ### Assessing Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420768 entries, 0 to 420767
# Data columns (total 17 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   year     420768 non-null  int64
#  1   month    420768 non-null  int64
#  2   day      420768 non-null  int64
#  3   hour     420768 non-null  int64
#  4   PM2.5    412029 non-null  float64
#  5   PM10     414319 non-null  float64
#  6   SO2      411747 non-null  float64
#  7   NO2      408652 non-null  float64
#  8   CO       400067 non-null  float64
#  9   O3       407491 non-null  float64
#  10  TEMP     420370 non-null  float64
#  11  PRES     420375 non-null  float64
#  12  DEWP     420365 non-null  float64
#  13  RAIN     420378 non-null  float64
#  14  wd       418946 non-null  object
#  15  WSPM     420450 non-null  float64
#  16  station  420768 non-null  object
# dtypes: float64(11), int64(4), object(2)
# memory usage: 54.6+ MB

# %%
df.nunique()
# Out:
# year          5
# month        12
# day          31
# hour         24
# PM2.5       888
# PM10       1084
# SO2         691
# NO2        1212
# CO          132
# O3         1598
# TEMP       2034
# PRES        726
# DEWP        645
# RAIN        253
# wd           16
# WSPM        117
# station      12
# dtype: int64

# %%
df.isna().sum()
# Out:
# year           0
# month          0
# day            0
# hour           0
# PM2.5       8739
# PM10        6449
# SO2         9021
# NO2        12116
# CO         20701
# O3         13277
# TEMP         398
# PRES         393
# DEWP         403
# RAIN         390
# wd          1822
# WSPM         318
# station        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Mengatur ukuran figure
plt.figure(figsize=(30, 16))

# Loop melalui setiap kolom dalam dataset
df_select_numeric = df.select_dtypes(include=['number']) # Hanya kolom numerik
for i, col in enumerate(df_select_numeric.columns, 1):
    plt.subplot(2, (len(df_select_numeric.columns) + 1) // 2, i)
    sns.boxplot(y=df_select_numeric[col])
    plt.title(f'Boxplot of {col}')
    plt.xlabel('')

plt.tight_layout()

# %%
df['RAIN'].value_counts()
# Out:
# RAIN
# 0.0     403858
# 0.1       3722
# 0.2       1841
# 0.3       1382
# 0.4        907
#          ...
# 36.1         1
# 18.2         1
# 26.7         1
# 18.9         1
# 22.4         1
# Name: count, Length: 253, dtype: int64

# %% [markdown]
# **Insight:**
# - Terdapat banyak sekali data kosong/missing value pada kolom-kolom tersebut
# - Tidak terdapat duplikasi data
# - Banyak sekali outlier pada data-data numerik

# %% [markdown]
# ### Cleaning Data

# %%
# Mengisi missing value kolom numerik dengan rata-rata
for col in ['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']:
    df[col] = df[col].fillna(value=df[col].mean())

# Mengisi missing value kolom kategorik dengan modus
df['wd'] = df['wd'].fillna(df['wd'].mode()[0])

#Melihat kembali data apakah masih ada missing value
print(df.isna().sum())
# Out:
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
# Imputasi outlier dengan IQR
def impute_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df[column] = np.where(df[column] < lower_bound, lower_bound, df[column])
    df[column] = np.where(df[column] > upper_bound, upper_bound, df[column])

    return df

df_no_outlier = df.copy()
# Lakukan hal yang sama untuk kolom lain yang mengandung outlier
for col in ['PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'WSPM', 'PM2.5', 'RAIN']:
    df_no_outlier = impute_outliers_iqr(df_no_outlier, col)

# %%
# Mengatur ukuran figure
plt.figure(figsize=(30, 16))

# Loop melalui setiap kolom dalam dataset
df_select_numeric = df_no_outlier.select_dtypes(include=['number']) # Hanya kolom numerik
for i, col in enumerate(df_select_numeric.columns, 1):
    plt.subplot(2, (len(df_select_numeric.columns) + 1) // 2, i)
    sns.boxplot(y=df_select_numeric[col])
    plt.title(f'Boxplot of {col}')
    plt.xlabel('')

plt.tight_layout()

# %%
df_no_outlier['RAIN'].value_counts()
# Out:
# RAIN
# 0.0    420768
# Name: count, dtype: int64

# %%
df['RAIN'].value_counts()
# Out:
# RAIN
# 0.0     403858
# 0.1       3722
# 0.2       1841
# 0.3       1382
# 0.4        907
#          ...
# 36.1         1
# 18.2         1
# 26.7         1
# 18.9         1
# 22.4         1
# Name: count, Length: 254, dtype: int64

# %% [markdown]
# **Insight:**
# - Mengisi nilai kosong/missing value dengan rata-rata pada kolom numerik dan modus pada kolom kategorik
# - Menangani outlier dengan metode imputation pada data copy, jika outlier bawah maka diisi dengan nilai batas bawah dan jika outlier atas maka diisi dengan nilai batas atas
# - Semua kolom outlier yang diisi dengan batas atas dan bawah menunjukkan hilangnya fitur-fitur seperti pada kolom 'RAIN' ketika dilakukan imputation maka nilai rain hannya 0.0 itu akan merusak fakta dari data yang artinya tidak pernah ada hujan dari tahun 2013-2017
# - Sehingga tidak perlu dilakukan imputation pada outlier

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
df_numeric = df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'WSPM']]
df_numeric.describe()
# Out:
#                PM2.5           PM10            SO2            NO2  \
# count  420768.000000  420768.000000  420768.000000  420768.000000
# mean       79.793428     104.602618      15.830835      50.638586
# std        79.978679      91.066422      21.417257      34.618463
# min         2.000000       2.000000       0.285600       1.026500
# 25%        21.000000      36.000000       3.000000      24.000000
# 50%        57.000000      84.000000       8.000000      45.000000
# 75%       109.000000     144.000000      19.000000      70.000000
# max       999.000000     999.000000     500.000000     290.000000
#
#                   CO             O3           TEMP           PRES  \
# count  420768.000000  420768.000000  420768.000000  420768.000000
# mean     1230.766454      57.372271      13.538976    1010.746982
# std      1131.283304      55.760484      11.430729      10.469162
# min       100.000000       0.214200     -19.900000     982.400000
# ...

# %%
# Set the figure size
plt.figure(figsize=(15, 10))

# Iterate through each numeric column and create a histogram
for i, col in enumerate(df_numeric.columns):
    plt.subplot(4, 3, i + 1)  # Adjust subplot layout as needed
    sns.histplot(df_numeric[col], kde=True)  # Added kde for density estimation
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# Analisis pertanyaan pertama
# - Bagaimana curah hujan tiap bulannya dalam kurun waktu satu tahun

# %%
df['RAIN'].value_counts()
# Out:
# RAIN
# 0.0     403858
# 0.1       3722
# 0.2       1841
# 0.3       1382
# 0.4        907
#          ...
# 36.1         1
# 18.2         1
# 26.7         1
# 18.9         1
# 22.4         1
# Name: count, Length: 254, dtype: int64

# %%
rain_avg = df.groupby(['year', 'month'])['RAIN'].mean().reset_index()

# Buat pivot table untuk heatmap
rain_pivot = rain_avg.pivot(index='year', columns='month', values='RAIN')

# Plot menggunakan heatmap
plt.figure(figsize=(24, 12))
sns.heatmap(rain_pivot, cmap="Blues", annot=True, fmt=".8f")
plt.title("Rata-rata Curah Hujan (mm) dari Tahun ke Tahun Berdasarkan Bulan")
plt.xlabel("Bulan")
plt.ylabel("Tahun")
plt.show()

# %% [markdown]
# Analisis pertanyaan kedua
# - Faktor apa yang menyebabkan curah hujan

# %%
# Set the figure size
plt.figure(figsize=(15, 10))

# Iterate through each numeric column and create a histogram
for i, col in enumerate(df_numeric.columns):
    plt.subplot(4, 3, i + 1)  # Adjust subplot layout as needed
    sns.scatterplot(x=df['RAIN'], y=df_numeric[col])  # Added kde for density estimation
    plt.title(f'Scatter Plot of RAIN vs {col}')
    plt.xlabel('RAIN')
    plt.ylabel(col)

plt.tight_layout()
plt.show()

# %%
df_numeric.corr()
# Out:
#           PM2.5      PM10       SO2       NO2        CO        O3      TEMP  \
# PM2.5  1.000000  0.879389  0.477582  0.658108  0.768664 -0.147204 -0.129715
# PM10   0.879389  1.000000  0.458519  0.645448  0.686716 -0.109983 -0.095395
# SO2    0.477582  0.458519  1.000000  0.491109  0.524707 -0.162283 -0.318067
# NO2    0.658108  0.645448  0.491109  1.000000  0.688207 -0.463523 -0.273864
# CO     0.768664  0.686716  0.524707  0.688207  1.000000 -0.305255 -0.317872
# O3    -0.147204 -0.109983 -0.162283 -0.463523 -0.305255  1.000000  0.585303
# TEMP  -0.129715 -0.095395 -0.318067 -0.273864 -0.317872  0.585303  1.000000
# PRES   0.018357 -0.017806  0.220414  0.171262  0.183004 -0.438657 -0.813300
# DEWP   0.113499  0.069767 -0.263895 -0.031135 -0.055615  0.307678  0.820115
# RAIN  -0.014156 -0.026360 -0.040029 -0.043357 -0.013008  0.023146  0.037635
# WSPM  -0.269023 -0.181835 -0.107549 -0.393849 -0.290044  0.291641  0.033029
#
#            PRES      DEWP      RAIN      WSPM
# ...

# %% [markdown]
# Analisis pertanyaan ketiga
# - Daerah dengan curah hujan tertinggi pada tiap tahun

# %%
df.groupby(['station', 'year'])['RAIN'].mean().reset_index().sort_values(by='RAIN', ascending=False)
# Out:
#           station  year      RAIN
# 53         Wanliu  2016  0.083385
# 7       Changping  2015  0.082568
# 12       Dingling  2015  0.082568
# 32        Huairou  2015  0.081023
# 27        Gucheng  2015  0.080876
# 28        Gucheng  2016  0.080789
# 3    Aotizhongxin  2016  0.079753
# 58  Wanshouxigong  2016  0.079753
# 18         Dongsi  2016  0.079753
# 48        Tiantan  2016  0.079753
# 23       Guanyuan  2016  0.079753
# 38   Nongzhanguan  2016  0.079753
# 33        Huairou  2016  0.076839
# 42         Shunyi  2015  0.076521
# 57  Wanshouxigong  2015  0.073192
# 47        Tiantan  2015  0.072880
# 37   Nongzhanguan  2015  0.072880
# 17         Dongsi  2015  0.072880
# 22       Guanyuan  2015  0.072686
# 2    Aotizhongxin  2015  0.072686
# 52         Wanliu  2015  0.072469
# 30        Huairou  2013  0.072331
# 50         Wanliu  2013  0.071582
# 0    Aotizhongxin  2013  0.071582
# 20       Guanyuan  2013  0.071582
# 25        Gucheng  2013  0.070003
# ...

# %% [markdown]
# **Insight:**
# - Melakukan pivot tabel untuk melihat rata-rata curah hujan tiap bulannya dalam kurun waktu 2013/2017
# - Melihat korelasi antara hujan dengan atribut yang lain
# - Melakukan pivot tabel untuk melihat rata-rata hujan tiap tahunnya di tiap kota

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana curah hujan tiap bulannya dalam kurun waktu 2013/2017?

# %%
# Group data by year and month, then sum the rainfall
rain_sum = df.groupby(['year', 'month'])['RAIN'].mean().reset_index()

# Create the line chart
plt.figure(figsize=(12, 6))
for year in rain_sum['year'].unique():
    year_data = rain_sum[rain_sum['year'] == year]
    plt.plot(year_data['month'], year_data['RAIN'], label=str(year))

plt.xlabel("Month")
plt.ylabel("Total Rainfall (mm)")
plt.title("Rata-rata curah hujan dari tahun 2013/2017")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Faktor apa yang menyebabkan curah hujan?

# %%
correlation_matrix = df_numeric.corr()
rain_correlation = correlation_matrix['RAIN'].sort_values(ascending=False)
rain_correlation
# Out:
# RAIN     1.000000
# DEWP     0.086291
# TEMP     0.037635
# O3       0.023146
# WSPM     0.021018
# CO      -0.013008
# PM2.5   -0.014156
# PM10    -0.026360
# SO2     -0.040029
# NO2     -0.043357
# PRES    -0.060948
# Name: RAIN, dtype: float64

# %% [markdown]
# ### Pertanyaan 3: Daerah mana dengan curah hujan tertinggi pada tiap tahun?

# %%
station_year_rain = df.groupby(['station', 'year'])['RAIN'].sum().reset_index().sort_values(by='RAIN', ascending=False)

plt.figure(figsize=(12, 6))
sns.barplot(x='station', y='RAIN', hue='year', data=station_year_rain)
plt.title('Total Rainfall by Station and Year')
plt.xlabel('Station')
plt.ylabel('Total Rainfall')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# * Pertanyaan 1
#   - Bulan ke-7 selalu menjadi puncak rata-rata curah hujan tertinggi dari tahun 2013/2017 dan Pada awal tahun dan akhir tahun curah hujan menurun. Hal ini menunjukkan bahwa :
#
#     Januari-Maret (1-3): Curah hujan cenderung rendah, jarang sekali terjadinya hujan.
#
#     April-Juli (4-7): Curah hujan mulai mengalami peningkatan dimana puncarnya terjadi pada bulan Juli, hampir tiap tahunnya.
#
#     Agustus-Desember (8-12): Curah hujan terjadi penurunan yang drastis pada bulan Agustus, tetapi mulai naik dan turun perlahan hingga bulan Desember.
#
# * Pertanyaan 2
#   - Curah hujan mungkin disebabkan oleh DEWP (Dew Point) dikarenakan memiliki nilai korelasi yang tertinggi dari atribut yang lain senilai 0.086291. Tetapi dengan nilai tersebut tidak dapat disimpulkan bahwa DEWP menjadi faktor utama turunnya hujan dikarenakan korelasinya cukup rendah dibawah 0,1, sedangkan korelasi yang kuat memiliki rentang nilai 0,7-0,9.
#
# * Pertanyaan 3
#   - Rata-rata curah hujan tertinggi terjadi pada tahunm 2016 hampir diseluruh stasiun
#   - Tahun 2013-2014 memiliki rata-rata curah hujan yang rendah dibanding tahun-tahun setelahnya
#   - Peningkatan curah hujan terjadi secara bertahap
#   -Stasiun seperti Wanliu, Tiantan, Dongsi, dan Aotizhongxin menunjukkan total curah hujan yang relatif tinggi dibandingkan stasiun lain.
#   -Stasiun Dingling dan Gucheng tampaknya memiliki curah hujan yang lebih rendah dibandingkan stasiun lainnya, terutama pada tahun 2013 dan 2014.
#   -Beberapa stasiun memiliki pola yang hampir seragam setiap tahunnya, tetapi sebagian lainnya menunjukkan fluktuasi yang lebih besar.
#   - Kota dengan rata-rata curah hujan tertinggi adalah Wanliu pada tahun 2016 dengan curah hujan senilai 0.083385

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1
#   - Pada awal musim dan akhir musim menunjukkan rendahnya curah hujan, kemungkinan pada rentang tersebut merupakan musim kemarau, dan pada bulan Juli merupakan puncak terjadnya hujan yang sering dapat dikatakan bulan tersebut merupakan musim hujan.
#
# - Conclution pertanyaan 2
#   - Faktor hujan tidak dipengaruhi oleh atribut-atribut yang ada dalam tabel tersebut
#
# - Conclution pertanyaan 3
#   - Curah hujan cenderung meningkat dari 2013 ke 2016, dengan puncak di tahun 2016.
#   - Beberapa stasiun menerima lebih banyak curah hujan secara konsisten, seperti Wanliu dan Tiantan.
#   - Stasiun Dingling dan Gucheng memiliki curah hujan lebih rendah dibandingkan stasiun lain.
#   - Tahun 2014 merupakan tahun dengan curah hujan paling rendah secara umum.
